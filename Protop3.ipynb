# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['image.cmap'] = 'inferno'
# %run functions.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt

slice = 2
i= slice


# Load the gas density data from the file
data = np.fromfile(f'/home/jupitergeci/fargo3d/outputs/fargo_sizes/gasdens{i:01d}.dat', 				dtype=np.float64)

# Load the domain_x.dat, domain_y.dat, and domain_z.dat files
domain_x = np.genfromtxt('/home/jupitergeci/fargo3d/outputs/fargo_sizes/domain_x.dat')        # coordenada azimuthal theta
domain_y = np.genfromtxt('/home/jupitergeci/fargo3d/outputs/fargo_sizes/domain_y.dat')[3:-3]  # coordenada radial r
domain_z = np.genfromtxt('/home/jupitergeci/fargo3d/outputs/fargo_sizes/domain_z.dat')[3:-3]  # coordenada co-latitud phi

# Get the dimensions of the data grid
NZ, NY, NX = len(domain_z)-1, len(domain_y)-1, len(domain_x)-1

print(NZ, NY, NX)

# Reshape the data array to match the dimensions of the grid
data = data.reshape(NZ, NY, NX)

# Select a slice along the phi-axis (the first dimension)
slice_index = NZ // 2  # Middle of the phi-axis
data_slice = data[slice_index, :, :]

# Define functions to create the X, Y, and Z grids
def Grilla_XY():
    # Create 2D grids
    R = 0.5 * (domain_y[1:] + domain_y[:-1])
    Phi = 0.5 * (domain_x[1:] + domain_x[:-1]) #En Fargo theta (azimuth) -> phi (coodenada X)
    P, R = np.meshgrid(Phi, R)
    # Convert the cylindrical coordinates (R, P) to Cartesian coordinates (X, Y)
    X, Y = R*np.cos(P), R*np.sin(P)
    return X, Y


X,Y = Grilla_XY()

# Select a slice along the phi-axis (the first dimension)

top = int( NZ // 1)- 1  # top of the phi-axis
mid = NZ // 2          # Middle of the phi-axis
slice_index = mid # Dónde se hace el corte
print(slice_index)
data_slice = data[slice_index, :, :]

print(X.shape)

# Plot the data in Cartesian coordinates
plt.figure(figsize=(8, 8))
plt.pcolormesh(X, Y, data_slice, cmap='inferno')
plt.colorbar(label='Density [g/cm²]')
plt.title(f'Gas Density Visualization (Phi-slice at index {slice_index})')
plt.xlabel('Y [AU]')
plt.ylabel('X [AU]')
plt.style.use("dark_background")
plt.axis('equal')
 
plt.show()
# Out:
# -1 380 380
# -1
# (380, 380)
# /tmp/ipykernel_28944/889317397.py:54: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(X, Y, data_slice, cmap='inferno')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import warnings

# Ignorar todas las advertencias
warnings.filterwarnings("ignore")
def update_plot(frame):
    """Actualiza la gráfica para el frame actual."""

    # Carga los datos para el frame actual
    data = np.fromfile(f'/home/jupitergeci/fargo3d/outputs/fargo_sizes/gasdens{frame:01d}.dat', dtype=np.float64)
    data = data.reshape(NZ, NY, NX)
    data_slice = data[slice_index, :, :]

    # Limpia la gráfica anterior
    plt.clf()

    # Crea la nueva gráfica
    plt.pcolormesh(X, Y, data_slice, cmap='inferno')
    plt.colorbar(label='Density [g/cm²]')
    plt.title(f'Gas Density Visualization (Phi-slice at index {slice_index}) - Frame {frame+1}')
    plt.xlabel('Y [AU]')
    plt.ylabel('X [AU]')
    plt.axis('equal')
    plt.style.use("dark_background")

    return plt.gcf()

domain_x = np.genfromtxt('/home/jupitergeci/fargo3d/outputs/fargo_sizes/domain_x.dat')
domain_y = np.genfromtxt('/home/jupitergeci/fargo3d/outputs/fargo_sizes/domain_y.dat')[3:-3]
domain_z = np.genfromtxt('/home/jupitergeci/fargo3d/outputs/fargo_sizes/domain_z.dat')[3:-3]
NZ, NY, NX = len(domain_z)-1, len(domain_y)-1, len(domain_x)-1
slice_index = NZ // 2
X, Y = Grilla_XY()


fig = plt.figure(figsize=(8, 8),facecolor="black")
anim = FuncAnimation(fig, update_plot, frames=slice, interval=200)  # 3 frames, intervalo de 200 ms

anim.save('gas_density_visualization.gif', writer='imagemagick')

# %%
from IPython.display import Image

gif = open('gas_density_visualization.gif', 'rb').read()


Image(gif)

# %% [markdown]
# Functions to read grid and parameters of FARGO3D

# %%
class read_parameters():
    def __init__(self, path=''):
        params = open(path+"variables.par",'r')
        lines = params.readlines()     # reading parfile                                                                                                                                       
        params.close()                 # closing parfile                                                                                                                                       
        par = {}                       # allocating a dictionary                                                                                                                               
        for line in lines:             # iterating over parfile                                                                                                                                
            name, value = line.split() # spliting name and value (first blank)                                                                                                                 
            try:
                float(value)           # first trying with float                                                                                                                               
            except ValueError:         # if it is not float                                                                                                                                    
                try:
                    int(value)         # we try with integer                                                                                                                                   
                except ValueError:     # if it is not integer, we know it is string                                                                                                            
                    value = '"' + value + '"'
            par[name] = value          # filling variable                                                                                                                                      
        self._params = par             # control atribute, good for debbuging                                                                                                                  
        for name in par:               # iterating over the dictionary                                                                                                                         
            exec("self."+name.lower()+"="+par[name]) # making atributes at runtime

class hydro_grid():
    def __init__(self,path=""):
        try:
            self.x = np.loadtxt(path+"domain_x.dat")+np.pi # AZIMUTH                                                                                                                          
        except IOError:
            print("IOError with domain_x.dat")
        try:
            self.y = np.loadtxt(path+"domain_y.dat")[3:-3] # RADIUS                                                                                                                     
        except IOError:
            print("IOError with domain_y.dat")
        try:
            self.z = np.loadtxt(path+"domain_z.dat")[3:-3] # COLATITUDE                                                                                                                 
        except:
            print("No vertical domain found - Is the simulation 2D?")

# %% [markdown]
# Load densities from FARGO3D output folder 'fargodir'

# %%
au = 1.5e13 # centimetros
msun= 2e33  # gramos


fargodir = "/home/jupitergeci/fargo3d/outputs/fargo_sizes/"
t = 1
par = read_parameters(path=fargodir)
gridF = hydro_grid(path=fargodir)
ndust = 3
names = ['gas','dust1','dust2','dust3']
dens = []
sizes= []
St   = []
dens.append(np.fromfile(fargodir+'gasdens%d.dat'%t).reshape(par.ny,par.nx))
for i in range(1,ndust+1):
    dens.append(np.fromfile(fargodir+names[i]+'dens%d.dat'%t).reshape(par.ny,par.nx))
    dens[i-1] *= par.mfactor*msun/(par.rfactor*au)**2
    sizes.append(par.amin*pow((par.amax/par.amin),(i-1.0)/(ndust-1.0)))
    St.append(np.pi/2.0*sizes[i-1]*par.rho_solid/dens[0])
print(sizes)
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(10,5))
ax1.imshow(dens[0],vmax = dens[0].max()/2)
ax2.imshow(dens[1],vmax = dens[1].max()/2)
ax3.imshow(dens[2],vmax = dens[2].max()/2)
ax4.imshow(dens[3],vmax = dens[3].max()/2)

ax1.set_xlabel(r'$\phi$')
ax1.set_ylabel(r'$r$')
plt.tight_layout()
plt.show()
# Out:
# [0.0001, 0.0031622776601683794, 0.1]

# %% [markdown]
# Set up the RADMC-3D grid

# %%
###Define grid similar to introduction but including the polar direction with theta = [pi/2-0.3,pi/2]###
class grid:
    def __init__(self,dims,bounds):
        self.nr, self.ntheta, self.nphi = dims[0],dims[1],dims[2]
        self.use_r  = 1 if self.nr > 1 else 0     # Which directions are included? 
        self.use_theta = 1 if self.ntheta > 1 else 0
        self.use_phi = 1 if self.nphi > 1 else 0
        self.theta_face = np.linspace(bounds[2],bounds[3],self.ntheta+1)
        self.theta = 0.5*(self.theta_face[1:]+self.theta_face[:-1])
        
r_in, r_out = par.ymin*par.rfactor*au, par.ymax*par.rfactor*au
if par.nz == 1:
    theta_up,theta_down = np.pi/2-0.3,np.pi/2+0.3
phi_l, phi_r = par.xmin,par.xmax
bounds = [r_in,r_out,theta_up,theta_down,phi_l,phi_r]
grid1 = grid([par.ny,50,par.nx],bounds) # This produces a 1D grid with 100 cells in radial direction
grid1.r0 = par.rfactor*au
grid1.r_face = gridF.y*grid1.r0
grid1.r = 0.5*(grid1.r_face[1:]+grid1.r_face[:-1])
grid1.phi_face   = gridF.x
grid1.phi = 0.5*(grid1.phi_face[1:]+grid1.phi_face[:-1])
grid_inp(grid1)                # this writes a file called 'amr_grid.inp' needed to run RADMC-3D

# %% [markdown]
# Expand the density in vertical direction and conform the fields to the RADMC-3D style

# %%
H0 = par.aspectratio*grid1.r0
f = par.flaringindex

coord       = np.meshgrid(grid1.r,grid1.theta,grid1.phi,indexing='ij')
rr       = coord[0] # centimetros
tt       = coord[1] # rad
pp       = coord[2] # rad
z        = np.cos(tt)*rr # centimetros

rho = []
for i in range(ndust):
    S_2d  = dens[i+1]
    S_3d  = np.zeros_like(rr)
    H_2d  = H0*(grid1.r/grid1.r0)**(1+f)
    H_2d  = np.meshgrid(H_2d,grid1.phi,indexing='ij')
    H_2d  = H_2d[0]
    H_2d *= np.sqrt(par.alpha/(par.alpha+St[i][:,:]))
    H_3d  = np.zeros_like(rr)
    for it in range(grid1.ntheta):
        S_3d[:,it,:] = S_2d[:,:]
        H_3d[:,it,:] = H_2d[:,:]
    rho.append(( S_3d / (np.sqrt(2.0*np.pi)*H_3d) ) * np.exp(-(z**2/H_3d**2)/2.0))


rho = np.array(rho)
plt.loglog(grid1.r,rho[0,:,:,0].sum(axis=-1))
plt.xlabel("Radio [AU]")
plt.ylabel("Density")
plt.grid(alpha=0.1)
plt.show()

plt.pcolormesh(rr[:,:,0],z[:,:,0],np.log10(rho[0,:,:,0]),vmin=-30)
plt.colorbar()
plt.show()

plt.pcolormesh(rr[:,0,:],pp[:,0,:],np.log10(rho[0,:,0,:]),vmin=-30)
plt.colorbar()
plt.show()

# %% [markdown]
# Write the density to file

# %%
dens_inp(grid1,rho,ndust)

# %% [markdown]
# Create the input files *wavelength_micron.inp*, *stars.inp*, *dustopac.inp*, *dustkappa_\*.inp* and *radmc3d.inp*

# %%
class wavelength:
    def __init__(self,lmin,lmax,nl):
        self.lmin = lmin
        self.lmax = lmax
        self.nlam = nl
        self.lam  = np.logspace(np.log10(lmin),np.log10(lmax),nl)
        
wl = wavelength(0.1,1e4,10)
wavelength_inp(wl) # this creates an input file called 'wavelength_micron.inp'

# %%
class stars:
    def __init__(self,p,T,R,M):
        self.x,self.y,self.z = p[0], p[1], p[2]
        self.T = T
        self.R = R
        self.M = M
        
allstars = []
Star1 = stars([0,0,0],6000.0,7e10,2e33)
allstars.append(Star1)
stars_inp(allstars,wl) # this creates a file 'stars.inp'

# %%
for i in range(ndust): 
    fac1 = sizes[i]/np.sqrt(10)*1e4
    fac2 = sizes[i]*np.sqrt(10)*1e4
    ! optool -radmc -l wavelength_micron.inp -a {fac1} {fac2} 3.5 10
    ! cp dustkappa.inp dustkappa_{names[i+1]}.inp

# %% [markdown]
# Optool its a independ library which we can reproduce specific composition of the material in the disk

# %%
ls
# Out:
# amr_grid.inp         dustkappa_dust3.inp            ppd.ipynb
# dust_density.inp     dustkappa.inp                  stars.inp
# dustkappa_dust1.inp  functions.ipynb                wavelength_micron.inp
# dustkappa_dust2.inp  gas_density_visualization.gif

# %%
dustopac_inp(names[1:]) # this creates a file called 'dustopac.inp'. The main purpose of this file is to
                         # tell the code how many dust species there are and where to find the according
                         # opacities

# %%
nphot_therm = 1e7
nphot_scat  = 1e6
nphot_spec  = 1e4
scattering_mode_max = 2
nthreads=8
radmc3d_inp(nphot_therm,nphot_scat,nphot_spec,
            scattering_mode_max,nthreads,mrw=0) # this creates a file called 'radmc3d.inp'
                                 # which more generally defines how the code
                                 # will be executed and which methods will
                                 # be employed.

# %% [markdown]
# Run the command to calculate the disk temperature and make a colormap of the temperature in the disk.

# %%
! radmc3d mctherm secondorder
# Out:
#
#  ================================================================
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2023 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, follow the
#                      RADMC-3D code on github
#              https://github.com/dullemond/radmc3d-2.0
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
#  ================================================================
#
#  Number of processors:            8
#  Number of threads in use:            8
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(26) to exactly pi/2...
#     Adjusting phi(nz+1) to exactly 2*pi...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
#        point source(s) while using spherical coordinate mode.
#        Since R_*<<R_in this is probably OK, but if you want
#        to play safe, then set istar_sphere = 1 in radmc3d.inp.
#  Note: Star 1 is taken to be a blackbody star
#        at a temperature T = 6000. Kelvin
#  Grid information (current status):
#    We have 7220000 branches, of which 7220000 are actual grid cells.
#    ---> 100.000% mem use for branches, and 100.000% mem use for actual cells.
#    No grid refinement is active. The AMR tree is not allocated (this saves memory).
#  Reading the heat source spatial distribution...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Reading dust data...
#  Reading dust densities...
#  Dust mass in species            1  =    3.1031223941334393E-008  Msun
#  Dust mass in species            2  =    2.9850607045060079E-008  Msun
#  Dust mass in species            3  =    3.1354110410646046E-008  Msun
#  Dust mass total =    9.2235941397040530E-008  Msun
#  Using dust scattering mode            2
#  Computing emissivity database...
#  Computing total input luminosities...
#  Modified Random Walk mode is switched OFF
#
#  Starting the thermal Monte Carlo simulation....
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread:           3 Photon nr:                 1000
#  Thread:           5 Photon nr:                 2000
#  Thread Nr           1 of           8 threads in total
#  Thread:           0 Photon nr:                 3000
#  Thread:           7 Photon nr:                 4000
#  Thread:           4 Photon nr:                 5000
#  Thread:           7 Photon nr:                 6000
#  Thread:           4 Photon nr:                 7000
#  Thread:           3 Photon nr:                 8000
#  Thread:           7 Photon nr:                 9000
#  Thread:           0 Photon nr:                10000
#  Thread:           7 Photon nr:                11000
#  Thread:           4 Photon nr:                12000
#  Thread:           4 Photon nr:                13000
#  Thread:           4 Photon nr:                14000
#  Thread:           6 Photon nr:                15000
#  Thread:           1 Photon nr:                16000
#  Thread:           4 Photon nr:                17000
#  Thread:           6 Photon nr:                18000
#  Thread:           1 Photon nr:                19000
#  Thread:           3 Photon nr:                20000
#  Thread:           4 Photon nr:                21000
#  Thread:           1 Photon nr:                22000
#  Thread:           3 Photon nr:                23000
#  Thread:           6 Photon nr:                24000
#  Thread:           2 Photon nr:                25000
#  Thread:           0 Photon nr:                26000
#  Thread:           7 Photon nr:                27000
#  Thread:           4 Photon nr:                28000
#  Thread:           1 Photon nr:                29000
#  Thread:           4 Photon nr:                30000
#  Thread:           3 Photon nr:                31000
#  Thread:           0 Photon nr:                32000
#  Thread:           4 Photon nr:                33000
#  Thread:           4 Photon nr:                34000
#  Thread:           0 Photon nr:                35000
#  Thread:           1 Photon nr:                36000
#  Thread:           0 Photon nr:                37000
#  Thread:           0 Photon nr:                38000
#  Thread:           5 Photon nr:                39000
#  Thread:           3 Photon nr:                40000
#  Thread:           7 Photon nr:                41000
#  Thread:           7 Photon nr:                42000
#  Thread:           1 Photon nr:                43000
#  Thread:           1 Photon nr:                44000
#  Thread:           0 Photon nr:                45000
#  Thread:           6 Photon nr:                46000
#  Thread:           5 Photon nr:                47000
#  Thread:           0 Photon nr:                48000
#  Thread:           1 Photon nr:                49000
#  Thread:           7 Photon nr:                50000
#  Thread:           2 Photon nr:                51000
#  Thread:           7 Photon nr:                52000
#  Thread:           2 Photon nr:                53000
#  Thread:           3 Photon nr:                54000
#  Thread:           0 Photon nr:                55000
#  Thread:           1 Photon nr:                56000
#  Thread:           0 Photon nr:                57000
#  Thread:           0 Photon nr:                58000
#  Thread:           1 Photon nr:                59000
#  Thread:           5 Photon nr:                60000
#  Thread:           3 Photon nr:                61000
#  Thread:           7 Photon nr:                62000
#  Thread:           5 Photon nr:                63000
#  Thread:           2 Photon nr:                64000
#  Thread:           4 Photon nr:                65000
#  Thread:           6 Photon nr:                66000
#  Thread:           4 Photon nr:                67000
#  Thread:           3 Photon nr:                68000
#  Thread:           3 Photon nr:                69000
#  Thread:           6 Photon nr:                70000
#  Thread:           3 Photon nr:                71000
#  Thread:           5 Photon nr:                72000
#  Thread:           4 Photon nr:                73000
#  Thread:           6 Photon nr:                74000
#  Thread:           2 Photon nr:                75000
#  Thread:           5 Photon nr:                76000
#  Thread:           4 Photon nr:                77000
#  Thread:           6 Photon nr:                78000
#  Thread:           5 Photon nr:                79000
#  Thread:           3 Photon nr:                80000
#  Thread:           0 Photon nr:                81000
#  Thread:           4 Photon nr:                82000
#  Thread:           5 Photon nr:                83000
#  Thread:           5 Photon nr:                84000
#  Thread:           7 Photon nr:                85000
#  Thread:           7 Photon nr:                86000
#  Thread:           1 Photon nr:                87000
#  Thread:           3 Photon nr:                88000
#  Thread:           2 Photon nr:                89000
#  Thread:           2 Photon nr:                90000
#  Thread:           5 Photon nr:                91000
#  Thread:           0 Photon nr:                92000
#  Thread:           0 Photon nr:                93000
#  Thread:           2 Photon nr:                94000
#  Thread:           5 Photon nr:                95000
#  Thread:           7 Photon nr:                96000
#  Thread:           7 Photon nr:                97000
#  Thread:           1 Photon nr:                98000
#  Thread:           1 Photon nr:                99000
#  Thread:           1 Photon nr:               100000
#  Thread:           3 Photon nr:               101000
#  Thread:           2 Photon nr:               102000
#  Thread:           2 Photon nr:               103000
#  Thread:           4 Photon nr:               104000
#  Thread:           1 Photon nr:               105000
#  Thread:           1 Photon nr:               106000
#  Thread:           5 Photon nr:               107000
#  Thread:           7 Photon nr:               108000
#  Thread:           6 Photon nr:               109000
#  Thread:           6 Photon nr:               110000
#  Thread:           6 Photon nr:               111000
#  Thread:           0 Photon nr:               112000
#  Thread:           5 Photon nr:               113000
#  Thread:           2 Photon nr:               114000
#  Thread:           7 Photon nr:               115000
#  Thread:           4 Photon nr:               116000
#  Thread:           5 Photon nr:               117000
#  Thread:           1 Photon nr:               118000
#  Thread:           0 Photon nr:               119000
#  Thread:           2 Photon nr:               120000
#  Thread:           6 Photon nr:               121000
#  Thread:           0 Photon nr:               122000
#  Thread:           1 Photon nr:               123000
#  Thread:           6 Photon nr:               124000
#  Thread:           5 Photon nr:               125000
#  Thread:           6 Photon nr:               126000
#  Thread:           6 Photon nr:               127000
#  Thread:           4 Photon nr:               128000
#  Thread:           0 Photon nr:               129000
#  Thread:           4 Photon nr:               130000
#  Thread:           5 Photon nr:               131000
#  Thread:           2 Photon nr:               132000
#  Thread:           4 Photon nr:               133000
#  Thread:           6 Photon nr:               134000
#  Thread:           6 Photon nr:               135000
#  Thread:           0 Photon nr:               136000
#  Thread:           5 Photon nr:               137000
#  Thread:           0 Photon nr:               138000
#  Thread:           4 Photon nr:               139000
#  Thread:           4 Photon nr:               140000
#  Thread:           1 Photon nr:               141000
#  Thread:           4 Photon nr:               142000
#  Thread:           0 Photon nr:               143000
#  Thread:           1 Photon nr:               144000
#  Thread:           1 Photon nr:               145000
#  Thread:           6 Photon nr:               146000
#  Thread:           3 Photon nr:              9973000
#  Thread:           1 Photon nr:              9974000
#  Thread:           2 Photon nr:              9975000
#  Thread:           2 Photon nr:              9976000
#  Thread:           5 Photon nr:              9977000
#  Thread:           0 Photon nr:              9978000
#  Thread:           2 Photon nr:              9979000
#  Thread:           2 Photon nr:              9980000
#  Thread:           0 Photon nr:              9981000
#  Thread:           4 Photon nr:              9982000
#  Thread:           6 Photon nr:              9983000
#  Thread:           4 Photon nr:              9984000
#  Thread:           2 Photon nr:              9985000
#  Thread:           2 Photon nr:              9986000
#  Thread:           0 Photon nr:              9987000
#  Thread:           0 Photon nr:              9988000
#  Thread:           1 Photon nr:              9989000
#  Thread:           3 Photon nr:              9990000
#  Thread:           6 Photon nr:              9991000
#  Thread:           7 Photon nr:              9992000
#  Thread:           2 Photon nr:              9993000
#  Thread:           6 Photon nr:              9994000
#  Thread:           1 Photon nr:              9995000
#  Thread:           3 Photon nr:              9996000
#  Thread:           1 Photon nr:              9997000
#  Thread:           3 Photon nr:              9998000
#  Thread:           0 Photon nr:              9999000
#  Thread:           4 Photon nr:             10000000
#  Elapsed time:   108.42454790499687
#  Done with Bjorkman & Wood Monte Carlo simulation
#  Using the parallel version of RADMC-3D
#  Number of parallel threads used:            8
#  Average number of abs/scat events per photon package =   0.21357580000000001
#  Average nr of times a photon stays in the same cell  =    6.5149375544179974E-002
#  Maximum nr of times a photon stayed in the same cell =           22
#  Saving results of thermal Monte Carlo
#  Done...

# %% [markdown]
# Generate the spectral energy distribution (SED) of the disk and plot it. Can you identify certain contributions to the SED?

# %%
! radmc3d sed incl 96.0
# Out:
#
#  ================================================================
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2023 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, follow the
#                      RADMC-3D code on github
#              https://github.com/dullemond/radmc3d-2.0
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
#  ================================================================
#
#  Number of processors:            8
#  Number of threads in use:            8
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(26) to exactly pi/2...
#     Adjusting phi(nz+1) to exactly 2*pi...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
#        point source(s) while using spherical coordinate mode.
#        Since R_*<<R_in this is probably OK, but if you want
#        to play safe, then set istar_sphere = 1 in radmc3d.inp.
#  Note: Star 1 is taken to be a blackbody star
#        at a temperature T = 6000. Kelvin
#  Grid information (current status):
#    We have 7220000 branches, of which 7220000 are actual grid cells.
#    ---> 100.000% mem use for branches, and 100.000% mem use for actual cells.
#    No grid refinement is active. The AMR tree is not allocated (this saves memory).
#  Reading the heat source spatial distribution...
#  Starting procedure for rendering images for the spectrum...
#    --> Including dust
#        No lines included...
#        No gas continuum included...
#  Reading dust data...
#  Reading dust densities...
#  Dust mass in species            1  =    3.1031223941334393E-008  Msun
#  Dust mass in species            2  =    2.9850607045060079E-008  Msun
#  Dust mass in species            3  =    3.1354110410646046E-008  Msun
#  Dust mass total =    9.2235941397040530E-008  Msun
#  Reading dust temperatures...
#  Rendering image(s)...
#  Doing scattering Monte Carlo simulation for lambda =   0.10000000000000001       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=  0.10000000000000001       micron
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread:           2 Photon nr:                 1000
#  Thread:           5 Photon nr:                 2000
#  Thread:           4 Photon nr:                 3000
#  Thread:           4 Photon nr:                 4000
#  Thread:           4 Photon nr:                 5000
#  Thread:           7 Photon nr:                 6000
#  Thread:           4 Photon nr:                 7000
#  Thread:           1 Photon nr:                 8000
#  Thread:           2 Photon nr:                 9000
#  Thread:           2 Photon nr:                10000
#  Elapsed time:  0.28418186099952436
#  Average number of scattering events per photon package =   0.26989999999999997
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =   0.10000000000000001       micron...
#  Doing scattering Monte Carlo simulation for lambda =   0.35938140000000002       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=  0.35938140000000002       micron
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread:           5 Photon nr:                 1000
#  Thread Nr           0 of           8 threads in total
#  Thread:           4 Photon nr:                 2000
#  Thread:           4 Photon nr:                 3000
#  Thread:           5 Photon nr:                 4000
#  Thread:           2 Photon nr:                 5000
#  Thread:           5 Photon nr:                 6000
#  Thread:           0 Photon nr:                 7000
#  Thread:           2 Photon nr:                 8000
#  Thread:           6 Photon nr:                 9000
#  Thread:           1 Photon nr:                10000
#  Elapsed time:  0.17005945699929725
#  Average number of scattering events per photon package =    1.2455000000000001
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =   0.35938140000000002       micron...
#  Doing scattering Monte Carlo simulation for lambda =    1.2915500000000000       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   1.2915500000000000       micron
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread:           3 Photon nr:                 1000
#  Thread:           4 Photon nr:                 2000
#  Thread Nr           0 of           8 threads in total
#  Thread:           0 Photon nr:                 3000
#  Thread:           3 Photon nr:                 4000
#  Thread:           5 Photon nr:                 5000
#  Thread:           6 Photon nr:                 6000
#  Thread:           3 Photon nr:                 7000
#  Thread:           2 Photon nr:                 8000
#  Thread:           0 Photon nr:                 9000
#  Thread:           3 Photon nr:                10000
#  Elapsed time:  0.12964819600165356
#  Average number of scattering events per photon package =    1.3102000000000000
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    1.2915500000000000       micron...
#  Doing scattering Monte Carlo simulation for lambda =    4.6415889999999997       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   4.6415889999999997       micron
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread:           1 Photon nr:                 1000
#  Thread:           5 Photon nr:                 2000
#  Thread:           6 Photon nr:                 3000
#  Thread:           1 Photon nr:                 4000
#  Thread:           7 Photon nr:                 5000
#  Thread:           2 Photon nr:                 6000
#  Thread:           5 Photon nr:                 7000
#  Thread:           6 Photon nr:                 8000
#  Thread:           1 Photon nr:                 9000
#  Thread:           0 Photon nr:                10000
#  Elapsed time:  0.23478704700028175
#  Average number of scattering events per photon package =   0.61750000000000005
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    4.6415889999999997       micron...
#  Doing scattering Monte Carlo simulation for lambda =    16.681009999999997       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   16.681009999999997       micron
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread:           3 Photon nr:                 1000
#  Thread:           4 Photon nr:                 2000
#  Thread:           0 Photon nr:                 3000
#  Thread:           3 Photon nr:                 4000
#  Thread:           0 Photon nr:                 5000
#  Thread:           6 Photon nr:                 6000
#  Thread:           4 Photon nr:                 7000
#  Thread:           5 Photon nr:                 8000
#  Thread:           0 Photon nr:                 9000
#  Thread:           6 Photon nr:                10000
#  Elapsed time:  0.15093482699739980
#  Average number of scattering events per photon package =    8.1900000000000001E-002
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    16.681009999999997       micron...
#  Doing scattering Monte Carlo simulation for lambda =    59.948430000000009       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   59.948430000000009       micron
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread:           4 Photon nr:                 1000
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           0 of           8 threads in total
#  Thread:           3 Photon nr:                 2000
#  Thread:           6 Photon nr:                 3000
#  Thread:           4 Photon nr:                 4000
#  Thread:           7 Photon nr:                 5000
#  Thread:           6 Photon nr:                 6000
#  Thread:           3 Photon nr:                 7000
#  Thread:           4 Photon nr:                 8000
#  Thread:           7 Photon nr:                 9000
#  Thread:           2 Photon nr:                10000
#  Elapsed time:  0.42698933100109571
#  Average number of scattering events per photon package =    5.8200000000000002E-002
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    59.948430000000009       micron...
#  Doing scattering Monte Carlo simulation for lambda =    215.44350000000000       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   215.44350000000000       micron
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread:           7 Photon nr:                 1000
#  Thread Nr           0 of           8 threads in total
#  Thread:           4 Photon nr:                 2000
#  Thread:           5 Photon nr:                 3000
#  Thread:           1 Photon nr:                 4000
#  Thread:           5 Photon nr:                 5000
#  Thread:           7 Photon nr:                 6000
#  Thread:           5 Photon nr:                 7000
#  Thread:           6 Photon nr:                 8000
#  Thread:           3 Photon nr:                 9000
#  Thread:           7 Photon nr:                10000
#  Elapsed time:  0.15162045900069643
#  Average number of scattering events per photon package =    3.3000000000000002E-002
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    215.44350000000000       micron...
#  Doing scattering Monte Carlo simulation for lambda =    774.26369999999997       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   774.26369999999997       micron
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread:           2 Photon nr:                 1000
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread:           5 Photon nr:                 2000
#  Thread:           2 Photon nr:                 3000
#  Thread:           0 Photon nr:                 4000
#  Thread:           4 Photon nr:                 5000
#  Thread:           1 Photon nr:                 6000
#  Thread:           2 Photon nr:                 7000
#  Thread:           7 Photon nr:                 8000
#  Thread:           1 Photon nr:                 9000
#  Thread:           1 Photon nr:                10000
#  Elapsed time:  0.15027154900235473
#  Average number of scattering events per photon package =    4.7999999999999996E-003
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    774.26369999999997       micron...
#  Doing scattering Monte Carlo simulation for lambda =    2782.5590000000002       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   2782.5590000000002       micron
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread:           5 Photon nr:                 1000
#  Thread:           5 Photon nr:                 2000
#  Thread:           2 Photon nr:                 3000
#  Thread:           2 Photon nr:                 4000
#  Thread:           2 Photon nr:                 5000
#  Thread:           7 Photon nr:                 6000
#  Thread:           6 Photon nr:                 7000
#  Thread:           6 Photon nr:                 8000
#  Thread:           7 Photon nr:                 9000
#  Thread:           7 Photon nr:                10000
#  Elapsed time:  0.42011049099892261
#  Average number of scattering events per photon package =    2.8999999999999998E-003
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    2782.5590000000002       micron...
#  Doing scattering Monte Carlo simulation for lambda =    10000.000000000000       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   10000.000000000000       micron
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread:           0 Photon nr:                 1000
#  Thread:           1 Photon nr:                 2000
#  Thread:           4 Photon nr:                 3000
#  Thread:           2 Photon nr:                 4000
#  Thread:           5 Photon nr:                 5000
#  Thread:           2 Photon nr:                 6000
#  Thread:           6 Photon nr:                 7000
#  Thread:           2 Photon nr:                 8000
#  Thread:           7 Photon nr:                 9000
#  Thread:           6 Photon nr:                10000
#  Elapsed time:  0.16522165000060340
#  Average number of scattering events per photon package =    8.9999999999999998E-004
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    10000.000000000000       micron...
#  Done rendering spectrum...
#  Writing spectrum to file...
#  Used scattering_mode=2, meaning: Henyey-Greenstein scattering approximation.
#  Done...

# %%
wls, sed = read_spectrum('spectrum.out',wl)
plt.title("SED")
plt.loglog(wls,sed,c='white', marker="o",linestyle="--")
#plt.ylim(1e-22,1e-20)
plt.xlabel("Wavelenght μm")
plt.ylabel("Flux [erg cm$^{⁻2}$ s$^{-1}$ Hz$^{-1}$ ]")
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# Make an image of the disk at $\lambda=1$mm.

# %%
! radmc3d image lambda 120 incl 96.0 posang 120.0
# Out:
#
#  ================================================================
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2023 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, follow the
#                      RADMC-3D code on github
#              https://github.com/dullemond/radmc3d-2.0
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
#  ================================================================
#
#  Number of processors:            8
#  Number of threads in use:            8
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(26) to exactly pi/2...
#     Adjusting phi(nz+1) to exactly 2*pi...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
#        point source(s) while using spherical coordinate mode.
#        Since R_*<<R_in this is probably OK, but if you want
#        to play safe, then set istar_sphere = 1 in radmc3d.inp.
#  Note: Star 1 is taken to be a blackbody star
#        at a temperature T = 6000. Kelvin
#  Grid information (current status):
#    We have 7220000 branches, of which 7220000 are actual grid cells.
#    ---> 100.000% mem use for branches, and 100.000% mem use for actual cells.
#    No grid refinement is active. The AMR tree is not allocated (this saves memory).
#  Reading the heat source spatial distribution...
#  Starting procedure for rendering image...
#    --> Including dust
#        No lines included...
#        No gas continuum included...
#  Reading dust data...
#  Reading dust densities...
#  Dust mass in species            1  =    3.1031223941334393E-008  Msun
#  Dust mass in species            2  =    2.9850607045060079E-008  Msun
#  Dust mass in species            3  =    3.1354110410646046E-008  Msun
#  Dust mass total =    9.2235941397040530E-008  Msun
#  Reading dust temperatures...
#  Rendering image(s)...
#  Doing scattering Monte Carlo simulation for lambda =    119.99999999999999       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   119.99999999999999       micron
#  Thread Nr           0 of           8 threads in total
#  Thread Nr           4 of           8 threads in total
#  Thread Nr           7 of           8 threads in total
#  Thread Nr           5 of           8 threads in total
#  Thread Nr           6 of           8 threads in total
#  Thread Nr           3 of           8 threads in total
#  Thread Nr           2 of           8 threads in total
#  Thread Nr           1 of           8 threads in total
#  Thread:           0 Photon nr:                 1000
#  Thread:           0 Photon nr:                 2000
#  Thread:           4 Photon nr:                 3000
#  Thread:           0 Photon nr:                 4000
#  Thread:           2 Photon nr:                 5000
#  Thread:           4 Photon nr:                 6000
#  Thread:           6 Photon nr:                 7000
#  Thread:           0 Photon nr:                 8000
#  Thread:           0 Photon nr:                 9000
#  Thread:           6 Photon nr:                10000
#  Thread:           5 Photon nr:                11000
#  Thread:           4 Photon nr:                12000
#  Thread:           4 Photon nr:                13000
#  Thread:           4 Photon nr:                14000
#  Thread:           3 Photon nr:                15000
#  Thread:           7 Photon nr:                16000
#  Thread:           2 Photon nr:                17000
#  Thread:           7 Photon nr:                18000
#  Thread:           1 Photon nr:                19000
#  Thread:           5 Photon nr:                20000
#  Thread:           4 Photon nr:                21000
#  Thread:           1 Photon nr:                22000
#  Thread:           1 Photon nr:                23000
#  Thread:           4 Photon nr:                24000
#  Thread:           2 Photon nr:                25000
#  Thread:           2 Photon nr:                26000
#  Thread:           7 Photon nr:                27000
#  Thread:           1 Photon nr:                28000
#  Thread:           1 Photon nr:                29000
#  Thread:           7 Photon nr:                30000
#  Thread:           2 Photon nr:                31000
#  Thread:           6 Photon nr:                32000
#  Thread:           3 Photon nr:                33000
#  Thread:           6 Photon nr:                34000
#  Thread:           4 Photon nr:                35000
#  Thread:           5 Photon nr:                36000
#  Thread:           0 Photon nr:                37000
#  Thread:           0 Photon nr:                38000
#  Thread:           4 Photon nr:                39000
#  Thread:           1 Photon nr:                40000
#  Thread:           5 Photon nr:                41000
#  Thread:           1 Photon nr:                42000
#  Thread:           2 Photon nr:                43000
#  Thread:           5 Photon nr:                44000
#  Thread:           2 Photon nr:                45000
#  Thread:           2 Photon nr:                46000
#  Thread:           1 Photon nr:                47000
#  Thread:           5 Photon nr:                48000
#  Thread:           5 Photon nr:                49000
#  Thread:           2 Photon nr:                50000
#  Thread:           5 Photon nr:                51000
#  Thread:           2 Photon nr:                52000
#  Thread:           6 Photon nr:                53000
#  Thread:           5 Photon nr:                54000
#  Thread:           2 Photon nr:                55000
#  Thread:           1 Photon nr:                56000
#  Thread:           0 Photon nr:                57000
#  Thread:           7 Photon nr:                58000
#  Thread:           2 Photon nr:                59000
#  Thread:           4 Photon nr:                60000
#  Thread:           7 Photon nr:                61000
#  Thread:           0 Photon nr:                62000
#  Thread:           4 Photon nr:                63000
#  Thread:           4 Photon nr:                64000
#  Thread:           6 Photon nr:                65000
#  Thread:           0 Photon nr:                66000
#  Thread:           4 Photon nr:                67000
#  Thread:           0 Photon nr:                68000
#  Thread:           0 Photon nr:                69000
#  Thread:           4 Photon nr:                70000
#  Thread:           0 Photon nr:                71000
#  Thread:           0 Photon nr:                72000
#  Thread:           4 Photon nr:                73000
#  Thread:           7 Photon nr:                74000
#  Thread:           5 Photon nr:                75000
#  Thread:           5 Photon nr:                76000
#  Thread:           6 Photon nr:                77000
#  Thread:           1 Photon nr:                78000
#  Thread:           1 Photon nr:                79000
#  Thread:           2 Photon nr:                80000
#  Thread:           2 Photon nr:               975000
#  Thread:           0 Photon nr:               976000
#  Thread:           3 Photon nr:               977000
#  Thread:           1 Photon nr:               978000
#  Thread:           0 Photon nr:               979000
#  Thread:           1 Photon nr:               980000
#  Thread:           1 Photon nr:               981000
#  Thread:           6 Photon nr:               982000
#  Thread:           2 Photon nr:               983000
#  Thread:           2 Photon nr:               984000
#  Thread:           0 Photon nr:               985000
#  Thread:           0 Photon nr:               986000
#  Thread:           2 Photon nr:               987000
#  Thread:           0 Photon nr:               988000
#  Thread:           7 Photon nr:               989000
#  Thread:           6 Photon nr:               990000
#  Thread:           6 Photon nr:               991000
#  Thread:           3 Photon nr:               992000
#  Thread:           0 Photon nr:               993000
#  Thread:           4 Photon nr:               994000
#  Thread:           3 Photon nr:               995000
#  Thread:           2 Photon nr:               996000
#  Thread:           0 Photon nr:               997000
#  Thread:           6 Photon nr:               998000
#  Thread:           6 Photon nr:               999000
#  Thread:           5 Photon nr:              1000000
#  Elapsed time:   15.620043879000150
#  Average number of scattering events per photon package =    3.7274000000000002E-002
#  Tip for speed-up: By default the settings of RADMC-3D are conservative (i.e. safe but slow).
#     A photon package in monochromatic Monte Carlo is only destroyed after tau_abs =  30.00
#     In most cases, however, an optical depth limit of 5 is enough.
#     You can (though at your own risk) speed this up by adding the following line to radmc3d.inp:
#     mc_scat_maxtauabs = 5.d0
#  Ray-tracing image for lambda =    119.99999999999999       micron...
#  Writing image to file...
#  Used scattering_mode=2, meaning: Henyey-Greenstein scattering approximation.
#  Diagnostics of flux-conservation (sub-pixeling):
#      Nr of main pixels (nx*ny)   =        10000
#      Nr of (sub)pixels raytraced =       406060
#      Nr of (sub)pixels used      =       307045
#      Increase of raytracing cost =    40.606000000000002
#      ----> This increase seems pretty large, and may cause
#            the ray-tracing to become very slow. It may be
#            worthwhile to figure out how/where/why the sub-pixeling
#            is so strong. Maybe you can do subpixeling diagnostics
#            by adding the keyword diag_subpix to the command line.
#            This dumps a file called subpixeling_diagnostics.out
#            which has, for each pixel or sub-pixel, a line containing:
#              x  y  dx  dy
#            where x,y are the image-plane coordinates of the pixel, and
#            dx,dy are the image-plane pixel sizes.
#
#            ** ANOTHER TIP for spherical coordinates: **
#            Maybe this happens because of refinement in R or Theta coordinates.
#            RADMC-3D will always try to make sub-pixeling such that it resolves
#            all cells as seen in projection. If you have extreme R-refinement this
#            will cause extreme sub-pixeling. Also if you use a linearly spaced grid
#            in R but you have a large span in R (max(R)/min(R)>>1), then the outer
#            R-grid will be very over-resolved (or the inner R-grid under-resolved).
#            It is then advisable to use a log-spaced grid.
#
#            You can moderate excessive sub-pixeling caused by fine R-grids by
#            setting the camera_min_drr parameter in radmc3d.inp to a value larger
#            than its default. Similar with camera_min_dangle for fine theta-grids.
#
#            If you use (instead) the command-line option "sloppy" then RADMC-3D
#            will set the camera_min_drr=0.1 and camera_min_dangle=0.1 as well as
#            camera_spher_cavity_relres=0.1, which are rather large values,
#            but hopefully still small enough.
#
#            All of these tricks to speed things up are, however, AT YOUR OWN RISK.
#            So you can use it, but it is wise to occasionally check without tricks.
#  Done...

# %%
plt.style.use("dark_background")
im = read_image('image.out')
plt.imshow(im)
plt.colorbar()
plt.show()

# %%
! radmc3d image lambda 20000 incl 0 posang 120.0
# Out:
#
#  ================================================================
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2023 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, follow the
#                      RADMC-3D code on github
#              https://github.com/dullemond/radmc3d-2.0
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
#  ================================================================
#
#  Number of processors:            8
#  Number of threads in use:            8
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(26) to exactly pi/2...
#     Adjusting phi(nz+1) to exactly 2*pi...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
#        point source(s) while using spherical coordinate mode.
#        Since R_*<<R_in this is probably OK, but if you want
#        to play safe, then set istar_sphere = 1 in radmc3d.inp.
#  Note: Star 1 is taken to be a blackbody star
#        at a temperature T = 6000. Kelvin
#  Grid information (current status):
#    We have 7220000 branches, of which 7220000 are actual grid cells.
#    ---> 100.000% mem use for branches, and 100.000% mem use for actual cells.
#    No grid refinement is active. The AMR tree is not allocated (this saves memory).
#  Reading the heat source spatial distribution...
#  Starting procedure for rendering image...
#    --> Including dust
#        No lines included...
#        No gas continuum included...
#  Reading dust data...
#  Reading dust densities...
#  Dust mass in species            1  =    3.1031223941334393E-008  Msun
#  Dust mass in species            2  =    2.9850607045060079E-008  Msun
#  Dust mass in species            3  =    3.1354110410646046E-008  Msun
#  Dust mass total =    9.2235941397040530E-008  Msun
#  Reading dust temperatures...
#  Rendering image(s)...
#  Doing scattering Monte Carlo simulation for lambda =    20000.000000000000       micron...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Using dust scattering mode            2
#  Wavelength nr            1  corresponding to lambda=   20000.000000000000       micron
#  ERROR in montecarlo module: Wavelength out of range of the global wavelength array
#  inu =           10 , freq_nr =           10
#  freq =    14989622900.000000        nu0,nu1 =    2997924580000000.0        29979245800.000000

# %%
plt.style.use("dark_background")
im = read_image('image.out')
plt.imshow(im)
plt.colorbar()
plt.show()

# %% [markdown]
# The main reason why we like to observe protoplanetary disks at mm-wavelengths is because the star is not very bright here, i.e. it does not us glare in our observation. That is different if we go to smaller wavelengths such as the optical (400-700nm) or near-infrared (700nm - 3µm). In these regimes, to expose the protoplanetary disk around a star, the main goal is to remove the star from the image. There are several techniques, one of the most successful one is polarized imaging. Here, one can make use of the fact that direct stellar light is unpolarized, while light gets polarized when it scatters off solid material - such as the dust in PPDs.\
